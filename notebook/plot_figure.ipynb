# %% [markdown]
# # plot figures from processed data

# %%
# conda install cartopy for visualization
# %conda install -c conda-forge cartopy -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys
sys.path.append('/home/dong1128/deepQPF_preparation')

import src.data_utils as du
from src.plot_map import plot
# Out:
# cartopy data path: /home/dong1128/.local/share/cartopy

# %%
file_path = '/work/dong1128/database/rain_rate_ten_min/2021/202106/20210604/20210604_0530.nc'
data, lon, lat = du.Netcdf4DataLoader(file_path).extract_data('qperr', 'lon', 'lat')

plot(lon, lat, data, lon.min(), lon.max(), lat.min(), lat.max())

# %%
file_name = "/work/dong1128/database/rain_rate_compressed/2019/201901/20190101/20190101_0120.nc.gz"
lon = np.linspace(118, 123.5, 441)
lat = np.linspace(20, 27, 561)
data = du.GzipDataLoader(file_name).extract_data(len(lat), len(lon))

plot(lon, lat, data, lon.min(), lon.max(), lat.min(), lat.max())
